# %%
import sys
from datetime import datetime
from pathlib import Path


import psycopg2
from kafka import KafkaConsumer
from models import ride_deserializer

server = 'localhost:9092'
topic_name = 'rides'

# Connect to PostgreSQL
conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='postgres'
)
conn.autocommit = True
cur = conn.cursor()

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-to-postgres',
    value_deserializer=ride_deserializer
)

print(f"Listening to {topic_name} and writing to PostgreSQL...")

count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
    cur.execute(
        """INSERT INTO processed_events
           (PULocationID, DOLocationID, trip_distance, total_amount, pickup_datetime)
           VALUES (%s, %s, %s, %s, %s)""",
        (ride.PULocationID, ride.DOLocationID,
         ride.trip_distance, ride.total_amount, pickup_dt)
    )
    count += 1
    if count % 100 == 0:
        print(f"Inserted {count} rows...")

consumer.close()
cur.close()
conn.close()
# Out:
# Listening to rides and writing to PostgreSQL...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#       9 print(f"Listening to {topic_name} and writing to PostgreSQL...")
#      11 count = 0
# ---> 12 for message in consumer:
#      13     ride = message.value
#      14     pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/consumer/group.py:725, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     715 def _poll_once(self, timer, max_records, update_offsets=True):
#     716     """Do one round of polling. In addition to checking for new data, this does
#     717     any needed heart-beating, auto-commits, and offset updates.
#     718
#    (...)    723         dict: Map of topic to list of records (may be empty).
#     724     """
# --> 725     if not self._coordinator.poll(timeout_ms=timer.timeout_ms):
#     726         log.debug('poll: timeout during coordinator.poll(); returning early')
#     727         return {}
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/coordinator/consumer.py:311, in ConsumerCoordinator.poll(self, timeout_ms)
#     308         log.debug('coordinator.poll: timeout updating metadata; returning early')
#     309         return False
# --> 311 if not self.ensure_active_group(timeout_ms=timer.timeout_ms):
#     312     log.debug('coordinator.poll: timeout in ensure_active_group; returning early')
#     313     return False
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/coordinator/base.py:451, in BaseCoordinator.ensure_active_group(self, timeout_ms)
#     449     return False
#     450 self._start_heartbeat_thread()
# --> 451 return self.join_group(timeout_ms=timer.timeout_ms)
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/coordinator/base.py:496, in BaseCoordinator.join_group(self, timeout_ms)
#     493     continue
#     495 future = self._initiate_join_group()
# --> 496 self._client.poll(future=future, timeout_ms=timer.timeout_ms)
#     497 if future.is_done:
#     498     self._reset_join_group_future()
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /Applications/XAMPP/xamppfiles/htdocs/de-zoomcamp/.venv/lib/python3.11/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
